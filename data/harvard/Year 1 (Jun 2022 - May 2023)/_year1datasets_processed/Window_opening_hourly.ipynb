# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
path = r"C:\Users\Noble Adike\Desktop\Coding\KPMG\kpmg-1a\data\harvard\Year 1 (Jun 2022 - May 2023)\Window_opening_hourly\48190960_Window_Opening.csv"
df = pd.read_csv(path)
df.head()
# Out:
#                    Timestamp  Z11_E_opening (%)  Z11_S_opening (%)  \
# 0  2022-06-01 00:00:00-04:00         100.000000         100.000000
# 1  2022-06-01 01:00:00-04:00         100.000000         100.000000
# 2  2022-06-01 02:00:00-04:00          20.150000          20.083333
# 3  2022-06-01 03:00:00-04:00           0.033333           0.066667
# 4  2022-06-01 04:00:00-04:00           0.000000           0.000000
#
#    Z12_S_opening (%)  Z13_S_opening (%)  Z13_W_opening (%)  Z15_N_opening (%)  \
# 0         100.000000         100.000000              100.0         100.000000
# 1         100.000000         100.000000              100.0         100.000000
# 2          19.716667          19.516667               19.6          19.733333
# 3           0.000000           0.000000                0.0           0.000000
# 4           0.000000           0.000000                0.0           0.000000
#
#    Z15_W_opening (%)  Z16_N_opening (%)  Z17_N_opening (%)  ...  \
# ...

# %%
df.describe()
# Out:
#        Z11_E_opening (%)  Z11_S_opening (%)  Z12_S_opening (%)  \
# count        8760.000000        8760.000000        8760.000000
# mean            6.351121           6.242700           9.630578
# std            21.885283          21.659287          25.372395
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%             0.000000           0.000000           0.000000
# 75%             0.000000           0.000000           0.000000
# max           100.000000         100.000000         100.000000
#
#        Z13_S_opening (%)  Z13_W_opening (%)  Z15_N_opening (%)  \
# count        8760.000000        8760.000000        8760.000000
# mean           10.395234          10.707400           9.404794
# std            26.321004          26.689573          26.129874
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Timestamp                    8760 non-null   object
#  1   Z11_E_opening (%)            8760 non-null   float64
#  2   Z11_S_opening (%)            8760 non-null   float64
#  3   Z12_S_opening (%)            8760 non-null   float64
#  4   Z13_S_opening (%)            8760 non-null   float64
#  5   Z13_W_opening (%)            8760 non-null   float64
#  6   Z15_N_opening (%)            8760 non-null   float64
#  7   Z15_W_opening (%)            8760 non-null   float64
#  8   Z16_N_opening (%)            8760 non-null   float64
#  9   Z17_N_opening (%)            8760 non-null   float64
#  10  Z1_Solar_damper_opening (%)  8760 non-null   float64
#  11  Z1_S_opening (%)             8760 non-null   float64
# ...

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df = df.set_index('Timestamp')
# Out:
# C:\Users\Noble Adike\AppData\Local\Temp\ipykernel_16736\330094659.py:1: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
df.plot(figsize=(15, 5))
plt.title('Window Opening Over Time')
plt.ylabel('Window Opening (0 = Closed, 1 = Open)')
plt.xlabel('Time')
plt.show()

# %%
df.isna().sum()
# Out:
# Z11_E_opening (%)                0
# Z11_S_opening (%)                0
# Z12_S_opening (%)                0
# Z13_S_opening (%)                0
# Z13_W_opening (%)                0
# Z15_N_opening (%)                0
# Z15_W_opening (%)                0
# Z16_N_opening (%)                0
# Z17_N_opening (%)                0
# Z1_Solar_damper_opening (%)      0
# Z1_S_opening (%)                 0
# Z21_E_opening (%)                0
# Z21_Sky_opening (%)              0
# Z21_S_opening (%)                0
# Z22_S_opening (%)                0
# Z23_Sky_opening (%)              0
# Z23_S_opening (%)                0
# Z23_W_opening (%)                0
# Z24_opening (%)                  0
# Z24_Sky_opening (%)              0
# Z25_N_opening (%)                0
# Z25_Sky_opening (%)              0
# Z25_W_opening (%)                0
# Z26_N_opening (%)                0
# Z27_N_opening (%)                0
# Z27_Sky_opening (%)              0
# Z31_Sky_opening (%)              0
# ...

# %%
df.loc[df['Z31_S_opening (%)']== None, 'Z31_S_opening (%)'] = np.nan

# %%
mean_value = df['Z31_S_opening (%)'].mean() 
df['Z31_S_opening (%)'] = df['Z31_S_opening (%)'].fillna(mean_value)

# %%
df['Z31_S_opening (%)'].isna().sum()
# Out:
# np.int64(0)
