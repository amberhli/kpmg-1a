# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
path = r"C:\Users\Noble Adike\Desktop\Coding\KPMG\kpmg-1a\data\harvard\Year 2 (Jun 2023 - May 2024)\Window_opening_hourly\48190945_Window_Opening.csv"
df = pd.read_csv(path)
df.head()
# Out:
#                    Timestamp  Z11_E_opening (%)  Z11_S_opening (%)  \
# 0  2023-06-01 00:00:00-04:00          11.166667           8.700000
# 1  2023-06-01 01:00:00-04:00           0.166667           1.133333
# 2  2023-06-01 02:00:00-04:00           0.000000           0.000000
# 3  2023-06-01 03:00:00-04:00           0.000000           0.000000
# 4  2023-06-01 04:00:00-04:00           0.000000           0.000000
#
#    Z12_S_opening (%)  Z13_S_opening (%)  Z13_W_opening (%)  Z15_N_opening (%)  \
# 0          39.266667          59.466667          73.433333           4.666667
# 1          28.466667          53.466667          67.500000           0.000000
# 2           5.266667          28.933333          44.566667           0.000000
# 3           0.000000          13.400000          31.400000           0.000000
# 4           0.000000           7.433333          25.433333           0.000000
#
#    Z15_W_opening (%)  Z16_N_opening (%)  Z17_N_opening (%)  ...  \
# 0           8.066667           4.666667                0.0  ...
# 1           0.000000           0.000000                0.0  ...
# 2           0.000000           0.000000                0.0  ...
# 3           0.000000           0.000000                0.0  ...
# 4           0.000000           0.000000                0.0  ...
#
#    Z27_N_opening (%)  Z27_Sky_opening (%)  Z31_Sky_opening (%)  \
# 0          97.100000            96.483333            91.866667
# 1           0.933333             0.833333            95.000000
# 2           4.333333             4.500000            82.233333
# 3          12.733333            12.700000            74.366667
# 4           1.933333             1.933333            67.866667
#
#    Z31_S_opening (%)  Z32_W_opening (%)  Z33_N_opening (%)  \
# 0          55.833333          67.800000          67.466667
# 1          60.566667          73.866667          67.666667
# 2          41.666667          51.666667          48.600000
# 3          36.333333          54.800000          36.100000
# 4          29.983333          59.683333          30.716667
#
#    Z33_Sky_opening (%)  Z3_N_opening (%)  Z4_N_opening (%)  Z5_N_opening (%)
# 0            67.466667               0.0         21.300000               0.0
# 1            67.733333               0.0         15.833333               0.0
# 2            48.666667               0.0          4.400000               0.0
# 3            36.100000               0.0          4.833333               0.0
# 4            30.166667               0.0          5.000000               0.0
#
# [5 rows x 35 columns]

# %%
df.describe()
# Out:
#        Z11_E_opening (%)  Z11_S_opening (%)  Z12_S_opening (%)  \
# count        8784.000000        8784.000000        8784.000000
# mean            7.685224           7.651575          11.162093
# std            24.344484          24.220347          27.201348
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%             0.000000           0.000000           0.000000
# 75%             0.000000           0.000000           0.387500
# max           100.000000         100.000000         100.000000
#
#        Z13_S_opening (%)  Z13_W_opening (%)  Z15_N_opening (%)  \
# count        8784.000000        8784.000000        8784.000000
# mean           11.940720          12.275931           6.333499
# std            28.252644          28.703100          22.331241
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%             0.000000           0.000000           0.000000
# 75%             0.666667           0.858333           0.000000
# max           100.000000         100.000000         100.000000
#
#        Z15_W_opening (%)  Z16_N_opening (%)  Z17_N_opening (%)  \
# count        8784.000000        8784.000000        8784.000000
# mean            6.315455           6.333499           5.419695
# std            22.300001          22.331241          20.512783
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%             0.000000           0.000000           0.000000
# 75%             0.000000           0.000000           0.000000
# max           100.000000         100.000000         100.000000
#
#        Z1_Solar_damper_opening (%)  ...  Z27_N_opening (%)  \
# count                       8784.0  ...        8784.000000
# mean                           0.0  ...          10.460967
# std                            0.0  ...          27.517851
# min                            0.0  ...           0.000000
# 25%                            0.0  ...           0.000000
# 50%                            0.0  ...           0.000000
# 75%                            0.0  ...           0.000000
# max                            0.0  ...         100.000000
#
#        Z27_Sky_opening (%)  Z31_Sky_opening (%)  Z31_S_opening (%)  \
# count          8784.000000          8784.000000        8784.000000
# mean              9.785383             7.951809          12.179114
# std              26.747230            24.936690          29.103888
# min               0.000000             0.000000           0.000000
# 25%               0.000000             0.000000           0.000000
# 50%               0.000000             0.000000           0.000000
# 75%               0.000000             0.000000           0.000000
# max             100.000000           100.000000          95.000000
#
#        Z32_W_opening (%)  Z33_N_opening (%)  Z33_Sky_opening (%)  \
# count        8784.000000        8784.000000          8784.000000
# mean           10.573696          10.760079            10.513185
# std            27.703598          27.251197            27.838785
# min             0.000000           0.000000             0.000000
# 25%             0.000000           0.000000             0.000000
# 50%             0.000000           0.000000             0.000000
# 75%             0.000000           0.000000             0.000000
# max            94.000000          94.000000           100.000000
#
#        Z3_N_opening (%)  Z4_N_opening (%)  Z5_N_opening (%)
# count       8784.000000        8784.00000       8784.000000
# mean           4.663927           6.83988          4.462257
# std           19.427259          21.01420         18.846118
# min            0.000000           0.00000          0.000000
# 25%            0.000000           0.00000          0.000000
# 50%            0.000000           0.00000          0.000000
# 75%            0.000000           0.00000          0.000000
# max          100.000000         100.00000        100.000000
#
# [8 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Timestamp                    8784 non-null   object
#  1   Z11_E_opening (%)            8784 non-null   float64
#  2   Z11_S_opening (%)            8784 non-null   float64
#  3   Z12_S_opening (%)            8784 non-null   float64
#  4   Z13_S_opening (%)            8784 non-null   float64
#  5   Z13_W_opening (%)            8784 non-null   float64
#  6   Z15_N_opening (%)            8784 non-null   float64
#  7   Z15_W_opening (%)            8784 non-null   float64
#  8   Z16_N_opening (%)            8784 non-null   float64
#  9   Z17_N_opening (%)            8784 non-null   float64
#  10  Z1_Solar_damper_opening (%)  8784 non-null   float64
#  11  Z1_S_opening (%)             8784 non-null   float64
#  12  Z21_E_opening (%)            8784 non-null   float64
#  13  Z21_Sky_opening (%)          8784 non-null   float64
#  14  Z21_S_opening (%)            8784 non-null   float64
#  15  Z22_S_opening (%)            8784 non-null   float64
#  16  Z23_Sky_opening (%)          8784 non-null   float64
#  17  Z23_S_opening (%)            8784 non-null   float64
#  18  Z23_W_opening (%)            8784 non-null   float64
#  19  Z24_opening (%)              8784 non-null   float64
#  20  Z24_Sky_opening (%)          8784 non-null   float64
#  21  Z25_N_opening (%)            8784 non-null   float64
#  22  Z25_Sky_opening (%)          8784 non-null   float64
#  23  Z25_W_opening (%)            8784 non-null   float64
#  24  Z26_N_opening (%)            8784 non-null   float64
#  25  Z27_N_opening (%)            8784 non-null   float64
#  26  Z27_Sky_opening (%)          8784 non-null   float64
#  27  Z31_Sky_opening (%)          8784 non-null   float64
#  28  Z31_S_opening (%)            8784 non-null   float64
#  29  Z32_W_opening (%)            8784 non-null   float64
#  30  Z33_N_opening (%)            8784 non-null   float64
#  31  Z33_Sky_opening (%)          8784 non-null   float64
#  32  Z3_N_opening (%)             8784 non-null   float64
#  33  Z4_N_opening (%)             8784 non-null   float64
#  34  Z5_N_opening (%)             8784 non-null   float64
# dtypes: float64(34), object(1)
# memory usage: 2.3+ MB

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df = df.set_index('Timestamp')
# Out:
# C:\Users\Noble Adike\AppData\Local\Temp\ipykernel_19880\330094659.py:1: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
df.plot(figsize=(15, 5))
plt.title('Window Opening Over Time')
plt.ylabel('Window Opening (0 = Closed, 1 = Open)')
plt.xlabel('Time')
plt.show()

# %%
df.isna().sum()
# Out:
# Z11_E_opening (%)              0
# Z11_S_opening (%)              0
# Z12_S_opening (%)              0
# Z13_S_opening (%)              0
# Z13_W_opening (%)              0
# Z15_N_opening (%)              0
# Z15_W_opening (%)              0
# Z16_N_opening (%)              0
# Z17_N_opening (%)              0
# Z1_Solar_damper_opening (%)    0
# Z1_S_opening (%)               0
# Z21_E_opening (%)              0
# Z21_Sky_opening (%)            0
# Z21_S_opening (%)              0
# Z22_S_opening (%)              0
# Z23_Sky_opening (%)            0
# Z23_S_opening (%)              0
# Z23_W_opening (%)              0
# Z24_opening (%)                0
# Z24_Sky_opening (%)            0
# Z25_N_opening (%)              0
# Z25_Sky_opening (%)            0
# Z25_W_opening (%)              0
# Z26_N_opening (%)              0
# Z27_N_opening (%)              0
# Z27_Sky_opening (%)            0
# Z31_Sky_opening (%)            0
# Z31_S_opening (%)              0
# Z32_W_opening (%)              0
# Z33_N_opening (%)              0
# Z33_Sky_opening (%)            0
# Z3_N_opening (%)               0
# Z4_N_opening (%)               0
# Z5_N_opening (%)               0
# dtype: int64

# %%
df.loc[df['Z31_S_opening (%)']== None, 'Z31_S_opening (%)'] = np.nan

# %%
mean_value = df['Z31_S_opening (%)'].mean() 
df['Z31_S_opening (%)'] = df['Z31_S_opening (%)'].fillna(mean_value)

# %%
df['Z31_S_opening (%)'].isna().sum()
# Out:
# np.int64(0)
